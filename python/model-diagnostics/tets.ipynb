# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pystan
import arviz as arvz

# %%
N_space = [500, 1000, 2000, 5000, 10000, 15000]
runtimes = [20,50,120,400,1000,2000]

# %%
fig, ax = plt.subplots()
ax.plot(N_space, runtimes, color='tab:orange')
ax.set_ylabel('Runtime')
ax.set_xlabel('Number of fitting samples')
ax.set_title('Runtime v.s N')
fig.tight_layout()
plt.savefig('runtime_plot.png')
plt.show()
